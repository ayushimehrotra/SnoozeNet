# %% [markdown]
# ##### Make sure to download SleepEDF and process the EDF files before using this notebook. This notebook is solely to replicate the results written in the paper.

# %% [markdown]
# ## Imports

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import os

from transformer import SnoozeTransformer
from dataloader import load_data,create_dataloaders
from train import cross_val, train_model

# %% [markdown]
# ## Run SnoozeNet

# %%
data = "SleepEDF20"
train_model(data)
# Out:
# Raw Data Loaded
# Fold #1
# Transformer Created
# torch.Size([32, 100, 40, 80])
# [INFO] Processing EEG Epoch #0
# [INFO] Allocated: 180.917248 MB
# Elapsed time: 0.9043700695037842 seconds
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# Epoch Done
# ...
